# %% [markdown]
# # Laplace Approximation

# %%
from numpy.linalg import inv
import pandas as pd
import numpy as np
import time
from scipy.stats import norm
from scipy.linalg import block_diag
def logsumexp(x):
    c = max(x)
    LSE = c + np.log(np.sum(np.exp(x - c)))
    return np.exp(x - LSE)
def Pi(x, y, mu, beta, tau):
    result = np.asarray((np.exp(x @ beta + tau * mu) / (1 + np.exp(x @ beta + tau * mu))))
    # Check if there are exp(0) cases, if true, return \pi = 1 correspondingly
    return np.nan_to_num(result, nan = 1)
def g(x, y, mu, beta, tau):
    g = sum(y * logsumexp(Pi(x, y, mu, beta, tau)) + (1 - y) * logsumexp(1 - Pi(x, y, mu, beta, tau))) \
    + np.nan_to_num(np.log(tau * (np.sqrt(2 * np.pi))**(-1) * np.exp(-mu**2/2)), nan=0)
    return g
def g_u(x, y, mu, beta, tau):
    return tau * sum((y - Pi(x, y, mu, beta, tau))) - mu
def g_b(x, y, mu, beta, tau):
    return np.sum(x * y - x * Pi(x, y, mu, beta, tau), axis = 0)
def g_t(x, y, mu, beta, tau):
    return mu * sum((y - Pi(x, y, mu, beta, tau)))
def g_uu(x, y, mu, beta, tau):
    result = np.nan_to_num(tau * np.asarray((np.exp(x @ beta + tau * mu) /\
                                              (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0)
    return - tau * sum(result) - 1
def g_bb(x, y, mu, beta, tau):
    result = 0
    for i in range(len(y)):
        result += -np.asarray(x[i].reshape(x.shape[1],1) @ x[i].reshape(1,x.shape[1])\
        * np.nan_to_num((np.exp(x[i] @ beta + tau * mu) / (1 + np.exp(x[i] @ beta + tau * tau * mu))**2), nan = 0))
    return result
def g_tt(x, y, mu, beta, tau):
    result = np.nan_to_num(mu * np.asarray((np.exp(x @ beta + tau * mu) /\
                                              (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0)
    return -mu * sum(result)
def g_ub(x, y, mu, beta, tau):
    result = np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) /\
                                       (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0)
    return -tau * np.sum(x * result, axis = 0)
def g_ut(x, y, mu, beta, tau):
    result = sum(y - Pi(x, y, mu, beta, tau))\
    - tau * sum(mu * np.nan_to_num(mu * np.asarray((np.exp(x @ beta + tau * mu) /\
                                          (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0))
    return result
def g_bt(x, y, mu, beta, tau):
    result = np.nan_to_num(mu * np.asarray((np.exp(x @ beta + tau * mu) /\
                                          (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0)
    return -np.sum(x * result, axis = 0)
def g_uuu(x, y, mu, beta, tau):
    return -tau * sum(-tau**2 * np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1)\
                             / (1 + np.exp(x @ beta + tau * mu))**3)), nan = 0))
def g_uub(x, y, mu, beta, tau): # add -
    return -tau * np.sum(-tau * x * np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1)\
                             / (1 + np.exp(x @ beta + tau * mu))**3)), nan = 0), axis = 0)
def g_ubb(x, y, mu, beta, tau):
    result = 0
    for i in range(len(y)):
        result += -np.asarray(x[i].reshape(x.shape[1],1) @ x[i].reshape(1,x.shape[1])\
                         * np.nan_to_num((np.exp(x[i] @ beta + tau * mu) * (np.exp(x[i] @ beta + tau * mu) - 1)\
                                       / (1 + np.exp(x[i] @ beta + tau * mu))**3), nan = 0))
    return -tau * result
def g_uut(x, y, mu, beta, tau):
    result = -tau * np.sum(np.nan_to_num((np.exp(x @ beta + tau * mu) * ((1 - tau * mu) * np.exp(x @ beta + tau * mu) + tau * mu + 1))\
    / (1 + np.exp(x @ beta + tau * mu))**3, nan = 0), axis = 0) - np.sum(np.nan_to_num(tau * np.asarray((np.exp(x @ beta + tau * mu) /\
                                              (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0))
    return result
def g_utt(x, y, mu, beta, tau):
    result = -2 * np.sum(np.nan_to_num(mu * np.asarray((np.exp(x @ beta + tau * mu) /\
                                          (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0), axis = 0)\
    - tau * np.sum( np.nan_to_num(-mu**2 * np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1) /\
                   (1 + np.exp(x @ beta + tau * mu))**3, nan = 0) )
    return result
def g_ubt(x, y, mu, beta, tau):
    left = np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) /\
                                       (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0)
    left = -np.sum(x * left, axis = 0)
    right = np.nan_to_num(np.asarray((mu * np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1))/\
                                    (np.exp(x @ beta + tau * mu) + 1)**3), nan = 0)
    right = -np.sum(x * right, axis = 0)
    return left + right
def g_uuuu(x, y, mu, beta, tau):
    result = -tau * np.sum( np.nan_to_num(-tau**3 * np.exp(2 * x @ beta + 2 * tau * mu)/(np.exp(x @ beta + tau * mu) + 1)**3\
                           - tau**3 * np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1)/(np.exp(x @ beta + tau * mu) + 1)**3\
                           + 3 * tau**3 * np.exp(2 * x @ beta + 2 * tau * mu) * (np.exp(x @ beta + tau * mu) - 1)/(np.exp(x @ beta + tau * mu) + 1)**4, nan = 0) )
    return result
def g_uuub(x, y, mu, beta, tau):
    result = -tau * np.sum( np.nan_to_num(tau**2 * x * np.exp(x @ beta + tau * mu)\
                           * (-4 * np.exp(x @ beta + tau * mu) + np.exp(2 * x @ beta + 2 * tau * mu) + 1)\
                           /(np.exp(x @ beta + tau * mu) + 1)**4, nan = 0), axis = 0 )
    return result
def g_uubb(x, y, mu, beta, tau):
    result = 0
    for i in range(len(y)):
        result += x[i].reshape(x.shape[1],1) @ x[i].reshape(1,x.shape[1]) * np.nan_to_num(np.exp(x[i] @ beta + tau * mu)\
        * (-4 * np.exp(x[i] @ beta + tau * mu) + np.exp(2 * x[i] @ beta + 2 * tau * mu) + 1)\
        / (np.exp(x[i] @ beta + tau * mu) + 1)**4, nan=0)
        
    result *= tau                     
        
    return -tau * result
def g_uuut(x, y, mu, beta, tau):
    left = -np.sum(-tau**2 * np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1)\
                             / (1 + np.exp(x @ beta + tau * mu))**3)), nan = 0))
    right = -tau * tau * np.sum(np.nan_to_num(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
                                                        + tau * mu * np.exp(2 * x @ beta + 2 * tau * mu)\
                                                        -2 * np.exp(2 * x @ beta + 2 * tau * mu) + tau * mu + 2)\
           /(np.exp(x @ beta + tau * mu) + 1)**4, nan=0))
    return left + right
def g_uutt(x, y, mu, beta, tau):
    left = -2 * np.sum(np.nan_to_num((np.exp(x @ beta + tau * mu)\
                                  * ((1 - tau * mu) * np.exp(x @ beta + tau * mu) + tau * mu + 1))\
    / (1 + np.exp(x @ beta + tau * mu))**3, nan = 0), axis = 0)
    right = -tau * mu * np.sum(np.nan_to_num(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
                                                        + tau * mu * np.exp(2 * x @ beta + 2 * tau * mu)\
                                                        -2 * np.exp(2 * x @ beta + 2 * tau * mu) + tau * mu + 2)\
           /(np.exp(x @ beta + tau * mu) + 1)**4, nan=0))
    return left + right
def g_uubt(x, y, mu, beta, tau):
    left = -np.sum(-tau * x * np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1)\
                             / (1 + np.exp(x @ beta + tau * mu))**3)), nan = 0), axis = 0)
    right = -tau * np.sum(x * np.nan_to_num(np.asarray(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
                                                             + tau * mu * np.exp(2 * x @ beta + 2 * tau * mu)\
                                                             - np.exp(2 * x @ beta + 2 * tau * mu) + tau * mu + 1)\
                          / (np.exp(x @ beta + tau * mu) + 1)**4), nan = 0), axis = 0)
    return left + right
def omega(x, y, mu, beta, tau):
    return np.sqrt(-1/g_uu(x, y, mu, beta, tau))
def mu_b(x, y, mu, beta, tau):
    return omega(x, y, mu, beta, tau)**2 * g_ub(x, y, mu, beta, tau)
def mu_bb(x, y, mu, beta, tau):
    result = omega(x, y, mu, beta, tau)**2 * (mu_b(x, y, mu, beta, tau).reshape(x.shape[1],1)\
                                              @ mu_b(x, y, mu, beta, tau).reshape(1,x.shape[1])\
                                              * g_uuu(x, y, mu, beta, tau)\
                                              + 2 * mu_b(x, y, mu, beta, tau).reshape(x.shape[1],1)\
                                              @ g_uub(x, y, mu, beta, tau).reshape(1,x.shape[1])\
                                              + g_ubb(x, y, mu, beta, tau))
    return result
def omega_b(x, y, mu, beta, tau):
    return 0.5 * omega(x, y, mu, beta, tau)**3 * (g_uuu(x, y, mu, beta, tau) * mu_b(x, y, mu, beta, tau)\
                                                    + g_uub(x, y, mu, beta, tau))
def mu_t(x, y, mu, beta, tau):
    return omega(x, y, mu, beta, tau)**2 * g_ut(x, y, mu, beta, tau)
def mu_tt(x, y, mu, beta, tau):
    result = omega(x, y, mu, beta, tau)**2 * (mu_t(x, y, mu, beta, tau)\
                                              * mu_t(x, y, mu, beta, tau)\
                                              * g_uuu(x, y, mu, beta, tau)\
                                              + 2 * mu_t(x, y, mu, beta, tau)\
                                              * g_uut(x, y, mu, beta, tau)\
                                              + g_utt(x, y, mu, beta, tau))
    return result
def mu_bt(x, y, mu, beta, tau):
    result = omega(x, y, mu, beta, tau)**2 * (mu_b(x, y, mu, beta, tau)\
                                              * mu_t(x, y, mu, beta, tau)\
                                              * g_uuu(x, y, mu, beta, tau)\
                                              + mu_b(x, y, mu, beta, tau)\
                                              * g_uut(x, y, mu, beta, tau)\
                                              + mu_t(x, y, mu, beta, tau)\
                                              * g_uub(x, y, mu, beta, tau)\
                                              + g_ubt(x, y, mu, beta, tau))
    return result
def omega_t(x, y, mu, beta, tau):
    return 0.5 * omega(x, y, mu, beta, tau)**3 * (g_uuu(x, y, mu, beta, tau) * mu_t(x, y, mu, beta, tau)\
                                                    + g_uut(x, y, mu, beta, tau))
def omega_bb(x, y, mu, beta, tau):
    result = 3/4 * omega(x, y, mu, beta, tau)**5 * (mu_b(x, y, mu, beta, tau) * g_uuu(x, y, mu, beta, tau)\
                                                      + g_uub(x, y, mu, beta, tau)).reshape(x.shape[1],1)\
     @ (mu_b(x, y, mu, beta, tau) * g_uuu(x, y, mu, beta, tau)\
        + g_uub(x, y, mu, beta, tau)).reshape(1,x.shape[1]) + 1/2 * omega(x, y, mu, beta, tau)**3\
     * (mu_bb(x, y, mu, beta, tau) * g_uuu(x, y, mu, beta, tau)\
        + (mu_b(x, y, mu, beta, tau).reshape(x.shape[1],1)\
           @ mu_b(x, y, mu, beta, tau).reshape(1,x.shape[1]) * g_uuuu(x, y, mu, beta, tau))\
        + mu_b(x, y, mu, beta, tau).reshape(x.shape[1],1) @ g_uuub(x, y, mu, beta, tau).reshape(1,x.shape[1])\
        + mu_b(x, y, mu, beta, tau).reshape(x.shape[1],1) @ g_uuub(x, y, mu, beta, tau).reshape(1,x.shape[1])\
        + g_uubb(x, y, mu, beta, tau)
       )
    return result
def omega_tt(x, y, mu, beta, tau):
    result = 3/4 * omega(x, y, mu, beta, tau)**5 * (mu_t(x, y, mu, beta, tau) * g_uuu(x, y, mu, beta, tau)\
                                                      + g_uut(x, y, mu, beta, tau))\
     * (mu_t(x, y, mu, beta, tau) * g_uuu(x, y, mu, beta, tau)\
        + g_uut(x, y, mu, beta, tau)) + 1/2 * omega(x, y, mu, beta, tau)**3\
     * (mu_tt(x, y, mu, beta, tau) * g_uuu(x, y, mu, beta, tau)\
        + (mu_t(x, y, mu, beta, tau)\
           * mu_t(x, y, mu, beta, tau) * g_uuuu(x, y, mu, beta, tau))\
        + mu_t(x, y, mu, beta, tau) * g_uuut(x, y, mu, beta, tau)\
        + mu_t(x, y, mu, beta, tau) * g_uuut(x, y, mu, beta, tau)\
        + g_uutt(x, y, mu, beta, tau)
       )
    return result
def omega_bt(x, y, mu, beta, tau):
    result = 3/4 * omega(x, y, mu, beta, tau)**5 * (mu_t(x, y, mu, beta, tau) * g_uuu(x, y, mu, beta, tau)\
                                                      + g_uut(x, y, mu, beta, tau))\
     * (mu_b(x, y, mu, beta, tau) * g_uuu(x, y, mu, beta, tau)\
        + g_uub(x, y, mu, beta, tau)) + 1/2 * omega(x, y, mu, beta, tau)**3\
     * (mu_bt(x, y, mu, beta, tau) * g_uuu(x, y, mu, beta, tau)\
        + (mu_b(x, y, mu, beta, tau)\
           * mu_t(x, y, mu, beta, tau) * g_uuuu(x, y, mu, beta, tau))\
        + mu_b(x, y, mu, beta, tau) * g_uuut(x, y, mu, beta, tau)\
        + mu_t(x, y, mu, beta, tau) * g_uuub(x, y, mu, beta, tau)\
        + g_uubt(x, y, mu, beta, tau)
       )
    return result
def lb_1(x, y, mu, beta, tau):
    l1 = omega_b(x, y, mu, beta, tau) / omega(x, y, mu, beta, tau)\
    + g_u(x, y, mu, beta, tau) * mu_b(x, y, mu, beta, tau) + g_b(x, y, mu, beta, tau)
    return l1
def lt_1(x, y, mu, beta, tau):
    l1 = omega_t(x, y, mu, beta, tau) / omega(x, y, mu, beta, tau)\
    + g_u(x, y, mu, beta, tau) * mu_t(x, y, mu, beta, tau) + g_t(x, y, mu, beta, tau)
    return l1
def lb_2(x, y, mu, beta, tau):
    l2 = omega(x, y, mu, beta, tau)**(-2) * (omega_bb(x, y, mu, beta, tau) * omega(x, y, mu, beta, tau)\
                                               - omega_b(x, y, mu, beta, tau).reshape(x.shape[1],1)\
                                               @ omega_b(x, y, mu, beta, tau).reshape(1,x.shape[1]))\
     + mu_bb(x, y, mu, beta, tau) * g_u(x, y, mu, beta, tau) + mu_b(x, y, mu, beta, tau).reshape(x.shape[1],1)\
     @ (mu_b(x, y, mu, beta, tau) * g_uu(x, y, mu, beta, tau) + g_ub(x, y, mu, beta, tau)).reshape(1,x.shape[1])\
     + mu_b(x, y, mu, beta, tau).reshape(x.shape[1],1) @ g_ub(x, y, mu, beta, tau).reshape(1,x.shape[1])\
     + g_bb(x, y, mu, beta, tau)
    return l2
def lt_2(x, y, mu, beta, tau):
    l2 = omega(x, y, mu, beta, tau)**(-2) * (omega_tt(x, y, mu, beta, tau) * omega(x, y, mu, beta, tau)\
                                               - omega_t(x, y, mu, beta, tau)\
                                               * omega_t(x, y, mu, beta, tau))\
     + mu_tt(x, y, mu, beta, tau) * g_u(x, y, mu, beta, tau) + mu_t(x, y, mu, beta, tau)\
     * (mu_t(x, y, mu, beta, tau) * g_uu(x, y, mu, beta, tau) + g_ut(x, y, mu, beta, tau))\
     + mu_t(x, y, mu, beta, tau) * g_ut(x, y, mu, beta, tau)\
     + g_tt(x, y, mu, beta, tau)
    return l2
def lbt_2(x, y, mu, beta, tau):
    l2 = omega(x, y, mu, beta, tau)**(-2) * (omega_bt(x, y, mu, beta, tau) * omega(x, y, mu, beta, tau)\
                                               - omega_b(x, y, mu, beta, tau)\
                                               * omega_t(x, y, mu, beta, tau))\
     + mu_bt(x, y, mu, beta, tau) * g_u(x, y, mu, beta, tau) + mu_b(x, y, mu, beta, tau)\
     * (mu_t(x, y, mu, beta, tau) * g_uu(x, y, mu, beta, tau) + g_ut(x, y, mu, beta, tau))\
     + mu_t(x, y, mu, beta, tau) * g_ub(x, y, mu, beta, tau)\
     + g_bt(x, y, mu, beta, tau)
    return l2
def max_mu(x, y, mu, beta, tau, max_iter=100):
    for step in range(max_iter):
        mu_new = mu - g_u(x, y, mu, beta, tau)/g_uu(x, y, mu, beta, tau)
        diff = mu_new - mu
        mu = mu_new
        if np.abs(diff) < 10**(-10):
            break;       
    return mu
def l(x, y, mu, beta, tau):
    l = 0.5 * np.log(2 * np.pi) + np.log(omega(x, y, mu, beta, tau)) + g(x, y, mu, beta, tau)
    return l
class LA:
    """
    A calss to run distributed GLMM

    ...

    Attributes
    ------------
    X : A list of DataFrames
        The data from different sites
    y : A list of arrays
        The binary outcomes from different sites
    beta : An array of params
        Fixed effects coefficents
    lam : Float
        Regularization term
    mu : Float
        The mixed effects coefficients
    tau : Float
        The hyperparameter of the variance of the random efffect

    """
    def __init__(self, X, y):        
        # Initialization
        self.p = X[0].shape[1]      # Number of variables
        self.n = len(y)             # Number of sites
        if isinstance(X[0], pd.DataFrame):
            self.var_name = X[0].columns
            self.X = [np.array(data) for data in X]
            self.y = [np.array(outcome).reshape(len(outcome),1) for outcome in y]
        else:
            var_name = []
            for i in range(self.p):
                var_name += ['X' + str(i+1)]
            self.var_name = var_name
            self.X = X
            self.y = y
        self.beta = np.repeat(0.1, self.p).reshape(self.p, 1)
        self.lam = 0
        self.mu = np.repeat(1, self.n)
        self.tau = 1
#         self.tau = np.repeat(1.0, self.n)
#         self.tau = 0.62909983
        self.df = pd.DataFrame
        self.score = np.nan
        self.predict = np.nan
        self.time = np.nan
        self.step = 0
        
    def fit(self, lam_it=0, lam_step=1, mu_it=2, theta_it=100):
        # Iteration
        pre_score = -10**10
        for self.lam in np.arange(0, lam_it+lam_step, lam_step):
#             print(f'In lambad = {self.lam}')
            for step_mu in range(mu_it):
#                 print(f'The {step_mu+1} step of mu')
                self.beta = self.beta.reshape(self.p, 1)
                for i in range(self.n):
#                     print('mu:\n', self.mu, '\n')
                    self.mu[i] = max_mu(self.X[i], self.y[i], self.mu[i], self.beta, self.tau)
#                 print('mu:\n', self.mu, '\n')
                for step_theta in range(theta_it):
#                     print(f'Step theta:{step_theta}')
                    theta = np.append(self.beta, self.tau)
#                     print('theta:\n', theta, '\n')
                    lb1 = 0
                    lb2 = 0
                    lt1 = 0
                    lt2 = 0
                    lbt2 = 0
#                     lt1 = []
#                     lt2 = []
                    for i in range(self.n):
                        lb1 += lb_1(self.X[i], self.y[i], self.mu[i], self.beta, self.tau)
                        lb2 += lb_2(self.X[i], self.y[i], self.mu[i], self.beta, self.tau)
                        lt1 += lt_1(self.X[i], self.y[i], self.mu[i], self.beta, self.tau)
                        lt2 += lt_2(self.X[i], self.y[i], self.mu[i], self.beta, self.tau)
                        lbt2 += lbt_2(self.X[i], self.y[i], self.mu[i], self.beta, self.tau)
#                         lt1 = np.append(lt1, [lt_1(self.X[i], self.y[i], self.mu[i], self.beta, self.tau[i])])
#                         lt2 = np.append(lt2, [lt_2(self.X[i], self.y[i], self.mu[i], self.beta, self.tau[i])])
#                     print('diff of tau:\n',lt1/lt2,'\n')
                    lb1 -= (2 * self.lam * self.beta.transpose())[0]
                    lt1 -= 2 * self.lam * self.tau
                    lb2 -= np.diag(np.repeat(2 * self.lam, self.p)) + 0.00001
                    lt2 = np.diag(lt2 - 2 * self.lam)#np.diag(lt2)
                    lt2 -= 0.00001
                    L1 = np.append(lb1, lt1)
#                     L2 = block_diag(lb2, lt2)
                    L2 = np.block([
                        [lb2, lbt2.reshape(self.p,1)],
                        [lbt2.reshape(1,self.p), lt2]
                    ])
                    delta = L1 @ inv(L2)
                    new_theta = theta - delta#.reshape(self.p+self.n, 1)
                    if (max(np.abs(delta[:-1])) < 10 **(-2)) and (delta[-1]<10**(-2)):
                        self.beta = new_theta[:self.p]
                        self.tau = new_theta[self.p:]
                        converge = True
                        self.step += step_theta+1
                        print('Done with iteration')
                        break;
                    if max(np.abs(delta)) > 10 **(2):
                        converge = False
                        print('Get out of iteration (delta > 10^(2)')
                        break;
                    if True in np.isnan(new_theta[:self.p]):
                        print('Error: NaN beta, rested to 0')
                        # Reset beta and tau
                        self.beta = np.repeat(0, self.p).reshape(self.p, 1)
                        break;
                    if True in np.isnan(new_theta[self.p:]):
                        print('Error: NaN tau, rested to 1.0')
                        # Reset beta and tau
                        converge = False
                        self.tau = 1.0
                        break;
                    if True in np.isnan(self.mu):
                        print('Error: NaN mu, rested to 0')
                        # Reset beta and tau
                        converge = False
                        self.mu = np.repeat(0.1, self.n)
                        break;                    
#                     if new_theta[-1] < 0:
# #                         print('Error: negative tau detectived')
#                         break;
                    self.beta = new_theta[:self.p].reshape(self.p, 1)
                    self.tau = new_theta[self.p:]
                    if step_theta == theta_it-1:
                        print('Error: Did not converged, reset all\n')
                        self.beta = np.repeat(0, self.p).reshape(self.p, 1)
                        self.mu = np.repeat(1, self.n)
                        self.tau = 1
                        converge = False
                        break;
#                     print('Step ', step_theta + 1, ':\n')
#                     print('delta:', delta, '\n')
#                     print('Beta:\n', self.beta, '\n')
#                     print('Diff:\n', delta, '\n')
#                     print('Lam:\n', self.lam, '\n')
#                     print('Score:\n',score,'\n')
#                     print('tau:', self.tau, '\n')
#                     print('mu:\n', self.mu, '\n')
                if not converge:
                    break;
#                 else:
#                     continue
#                 break;
                    
#                     print('l:\n',l(self.X[i], self.y[i], self.mu[i], self.beta, self.tau) - sum(self.lam * (self.beta) **2),'\n')

            score = 0
            predict = []
            self.beta = new_theta[:self.p].reshape(self.p, 1)
            for i in range(self.n):
#                     print('Lam:\n', self.lam, '\n')
#                     print('tau:', self.tau, '\n')
#                     print('Beta:\n', self.beta, '\n')
                score += l(self.X[i], self.y[i], self.mu[i], self.beta, self.tau) - sum(self.lam * (self.beta) **2)
                predict += [Pi(self.X[i], self.y[i], self.mu[i], self.beta, self.tau)]
#             print('score:\n', score, '\n')
            if True in np.isnan(score):
                print('Error: NaN score')
                break;
            if (np.mean(score) > pre_score) and converge:
                optimized_beta = self.beta
                optimized_mu = self.mu
                optimized_lam = self.lam
                optimized_tau = self.tau
                optimized_step = self.step
                # reset
                pre_score = score
                optimized_score = score
#                 self.tau = np.repeat(1.0, self.n)

        # Returning data
#         optimized_beta[0] = optimized_beta[0] + np.mean(optimized_tau * optimized_mu)
        self.beta = optimized_beta
        self.mu = optimized_mu
        self.lam = optimized_lam
        self.tau = optimized_tau
        self.score = optimized_score
        self.predict = np.concatenate(predict)
        self.step = optimized_step


        X = np.concatenate(self.X)
        
        y = np.concatenate(self.y)

        V = np.diagflat(self.predict * (1 - self.predict) + 0.0001)

        SE = np.sqrt(np.diag(inv(np.transpose(X) @ V @ X))).reshape(self.p,1)

        Z = self.beta/SE

        P = 2 * norm.cdf(-1 * np.abs(Z))

        CI_025  = self.beta - 1.959964 * SE
        CI_975  = self.beta + 1.959964 * SE

        self.df = pd.DataFrame({'Coef': np.transpose(self.beta)[0], 'Std.Err': np.transpose(SE)[0],
                           'z': np.transpose(Z)[0], 'P-value': np.transpose(P)[0],
                           '[0.025': np.transpose(CI_025)[0], '0.975]': np.transpose(CI_975)[0]},
                          index = self.var_name)
        
        return self

# %%
class LA:
    """
    A calss to run distributed GLMM

    ...

    Attributes
    ------------
    X : A list of DataFrames
        The data from different sites
    y : A list of arrays
        The binary outcomes from different sites
    beta : An array of params
        Fixed effects coefficents
    lam : Float
        Regularization term
    mu : Float
        The mixed effects coefficients
    tau : Float
        The hyperparameter of the variance of the random efffect

    """
    def __init__(self, X, y):        
        # Initialization
        self.p = X[0].shape[1]      # Number of variables
        self.n = len(y)             # Number of sites
        if isinstance(X[0], pd.DataFrame):
            self.var_name = X[0].columns
            self.X = [np.array(data) for data in X]
            self.y = [np.array(outcome).reshape(len(outcome),1) for outcome in y]
        else:
            var_name = []
            for i in range(self.p):
                var_name += ['X' + str(i+1)]
            self.var_name = var_name
            self.X = X
            self.y = y
        self.beta = np.repeat(0.1, self.p).reshape(self.p, 1)
        self.lam = 0
        self.mu = np.repeat(1, self.n)
        self.tau = 1
#         self.tau = np.repeat(1.0, self.n)
#         self.tau = 0.62909983
        self.df = pd.DataFrame
        self.score = np.nan
        self.predict = np.nan
        self.time = np.nan
        
    def fit(self, lam_it=0, lam_step=1, mu_it=2, theta_it=100):
        # Iteration
        pre_score = -10**10
        for self.lam in np.arange(0, lam_it+lam_step, lam_step):
            print(f'In lambad = {self.lam}')
            for step_mu in range(mu_it):
                print(f'The {step_mu+1} step of mu')
                self.beta = self.beta.reshape(self.p, 1)
                for i in range(self.n):
#                     print('mu:\n', self.mu, '\n')
                    self.mu[i] = max_mu(self.X[i], self.y[i], self.mu[i], self.beta, self.tau)
#                 print('mu:\n', self.mu, '\n')
                for step_theta in range(theta_it):
                    theta = np.append(self.beta, self.tau)
#                     print('theta:\n', theta, '\n')
                    lb1 = 0
                    lb2 = 0
                    lt1 = 0
                    lt2 = 0
                    lbt2 = 0
#                     lt1 = []
#                     lt2 = []
                    for i in range(self.n):
                        lb1 += lb_1(self.X[i], self.y[i], self.mu[i], self.beta, self.tau)
                        lb2 += lb_2(self.X[i], self.y[i], self.mu[i], self.beta, self.tau)
                        lt1 += lt_1(self.X[i], self.y[i], self.mu[i], self.beta, self.tau)
                        lt2 += lt_2(self.X[i], self.y[i], self.mu[i], self.beta, self.tau)
                        lbt2 += lbt_2(self.X[i], self.y[i], self.mu[i], self.beta, self.tau)
#                         lt1 = np.append(lt1, [lt_1(self.X[i], self.y[i], self.mu[i], self.beta, self.tau[i])])
#                         lt2 = np.append(lt2, [lt_2(self.X[i], self.y[i], self.mu[i], self.beta, self.tau[i])])
#                     print('diff of tau:\n',lt1/lt2,'\n')
                    lb1 -= (2 * self.lam * self.beta.transpose())[0]
                    lt1 -= 2 * self.lam * self.tau
                    lb2 -= np.diag(np.repeat(2 * self.lam, self.p)) + 0.00001
                    lt2 = np.diag(lt2 - 2 * self.lam)#np.diag(lt2)
                    lt2 -= 0.00001
                    L1 = np.append(lb1, lt1)
#                     L2 = block_diag(lb2, lt2)
                    L2 = np.block([
                        [lb2, lbt2.reshape(self.p,1)],
                        [lbt2.reshape(1,self.p), lt2]
                    ])
                    delta = L1 @ inv(L2)
                    new_theta = theta - delta#.reshape(self.p+self.n, 1)
                    if (max(np.abs(delta[:-1])) < 10 **(-2)) and (delta[-1]<10**(-2)):
                        self.beta = new_theta[:self.p]
                        self.tau = new_theta[self.p:]
                        converge = True
                        print('Done with iteration')
                        break;
                    if max(np.abs(delta)) > 10 **(2):
                        converge = False
                        print('Get out of iteration (delta > 10^(2)')
                        break;
                    if True in np.isnan(new_theta[:self.p]):
                        print('Error: NaN beta, rested to 0')
                        # Reset beta and tau
                        self.beta = np.repeat(0, self.p).reshape(self.p, 1)
                        break;
                    if True in np.isnan(new_theta[self.p:]):
                        print('Error: NaN tau, rested to 1.0')
                        # Reset beta and tau
                        converge = False
                        self.tau = 1.0
                        break;
                    if True in np.isnan(self.mu):
                        print('Error: NaN mu, rested to 0')
                        # Reset beta and tau
                        converge = False
                        self.mu = np.repeat(0.1, self.n)
                        break;                    
#                     if new_theta[-1] < 0:
# #                         print('Error: negative tau detectived')
#                         break;
                    self.beta = new_theta[:self.p].reshape(self.p, 1)
                    self.tau = new_theta[self.p:]
                    if step_theta == theta_it-1:
                        print('Error: Did not converged, reset all\n')
                        self.beta = np.repeat(0, self.p).reshape(self.p, 1)
                        self.mu = np.repeat(1, self.n)
                        self.tau = 1
                        converge = False
                        break;
#                     print('Step ', step_theta + 1, ':\n')
#                     print('delta:', delta, '\n')
#                     print('Beta:\n', self.beta, '\n')
#                     print('Diff:\n', delta, '\n')
#                     print('Lam:\n', self.lam, '\n')
#                     print('Score:\n',score,'\n')
#                     print('tau:', self.tau, '\n')
#                     print('mu:\n', self.mu, '\n')
                if not converge:
                    break;
#                 else:
#                     continue
#                 break;
                    
#                     print('l:\n',l(self.X[i], self.y[i], self.mu[i], self.beta, self.tau) - sum(self.lam * (self.beta) **2),'\n')

            score = 0
            predict = []
            self.beta = new_theta[:self.p].reshape(self.p, 1)
            for i in range(self.n):
#                     print('Lam:\n', self.lam, '\n')
#                     print('tau:', self.tau, '\n')
#                     print('Beta:\n', self.beta, '\n')
                score += l(self.X[i], self.y[i], self.mu[i], self.beta, self.tau) - sum(self.lam * (self.beta) **2)
                predict += [Pi(self.X[i], self.y[i], self.mu[i], self.beta, self.tau)]
            print('score:\n', score, '\n')
            if True in np.isnan(score):
                print('Error: NaN score')
                break;
            if (np.mean(score) > pre_score) and converge:
                optimized_beta = self.beta
                optimized_mu = self.mu
                optimized_lam = self.lam
                optimized_tau = self.tau
                # reset
                pre_score = score
                optimized_score = score
#                 self.tau = np.repeat(1.0, self.n)

        # Returning data
        optimized_beta[0] = optimized_beta[0] + np.mean(optimized_tau * optimized_mu)
        self.beta = optimized_beta
        self.mu = optimized_mu
        self.lam = optimized_lam
        self.tau = optimized_tau
        self.score = optimized_score
        self.predict = np.concatenate(predict)


        X = np.concatenate(self.X)
        
        y = np.concatenate(self.y)

        V = np.diagflat(self.predict * (1 - self.predict) + 0.0001)

        SE = np.sqrt(np.diag(inv(np.transpose(X) @ V @ X))).reshape(self.p,1)

        Z = self.beta/SE

        P = 2 * norm.cdf(-1 * np.abs(Z))

        CI_025  = self.beta - 1.959964 * SE
        CI_975  = self.beta + 1.959964 * SE

        self.df = pd.DataFrame({'Coef': np.transpose(self.beta)[0], 'Std.Err': np.transpose(SE)[0],
                           'z': np.transpose(Z)[0], 'P-value': np.transpose(P)[0],
                           '[0.025': np.transpose(CI_025)[0], '0.975]': np.transpose(CI_975)[0]},
                          index = self.var_name)
        
        return self

# %%
p = 10
np.random.seed(233)
true_beta = (np.random.rand(p,1) - np.random.rand(p,1)) * 10
true_tau = np.random.rand(1)
true_mu = np.random.rand(2)
X1 = (np.random.rand(1000, p) - np.random.rand(1000, p)) * 10
p1 = 1 / (1 + np.exp(-(X1 @ true_beta + np.random.normal(true_mu[0], true_tau, 1000).reshape(1000, 1))))
y1 = np.random.binomial(1,p1)
X2 = (np.random.rand(1000, p) - np.random.rand(1000, p)) * 10
p2 = 1 / (1 + np.exp(-(X2 @ true_beta + np.random.normal(true_mu[1], true_tau, 1000).reshape(1000, 1))))
y2 = np.random.binomial(1,p2)
X = [X1, X2]
y = [y1, y2]

# %%
# pd.DataFrame(X1).to_csv('/Users/wli17/Documents/GLMM/GLMM/X1_test.csv', header=None, index=None)
# pd.DataFrame(X2).to_csv('/Users/wli17/Documents/GLMM/GLMM/X2_test.csv', header=None, index=None)
# pd.DataFrame(y1).to_csv('/Users/wli17/Documents/GLMM/GLMM/y1_test.csv', header=None, index=None)
# pd.DataFrame(y2).to_csv('/Users/wli17/Documents/GLMM/GLMM/y2_test.csv', header=None, index=None)

# %%
true_tau
# Out:
# array([0.42244813])

# %%
true_mu
# Out:
# array([0.2513114 , 0.53939061])

# %%
model = LA(X, y).fit(lam_it=2)
# Out:
# In lambad = 0
# The 1 step of mu
# Step theta:0
# Step theta:1
# Step theta:2
# Step theta:3
# Step theta:4
# Step theta:5
# Step theta:6
# Step theta:7
# Step theta:8
# Step theta:9
# Step theta:10
# Step theta:11
# Done with iteration
# The 2 step of mu
# Step theta:0
# Done with iteration
# score:
#  [0.42859166]
#
# In lambad = 1
# The 1 step of mu
# Step theta:0
# Step theta:1
# Step theta:2
# Step theta:3
# Step theta:4
# Step theta:5
# Step theta:6
# Done with iteration
# The 2 step of mu
# Step theta:0
# Done with iteration
# score:
#  [-48.19082457]
#
# In lambad = 2
# The 1 step of mu
# Step theta:0
# Step theta:1
# Step theta:2
# Step theta:3
# Step theta:4
# Step theta:5
# Done with iteration
# The 2 step of mu
# Step theta:0
# Done with iteration
# score:
#  [-65.01836753]

# %%
model.step
# Out:
# 13

# %%
step = []
for sample_size in [100, 500, 1000, 2000, 5000]:
    p = 50
    np.random.seed(2)
    true_beta = (np.random.rand(p,1) - np.random.rand(p,1)) * 10
    true_tau = np.random.rand(1)
    true_mu = np.random.rand(2)
    X1 = (np.random.rand(sample_size, p) - np.random.rand(sample_size, p)) * 10
    p1 = 1 / (1 + np.exp(-(X1 @ true_beta + np.random.normal(true_mu[0], true_tau, sample_size).reshape(sample_size, 1))))
    y1 = np.random.binomial(1,p1)
    X2 = (np.random.rand(sample_size, p) - np.random.rand(sample_size, p)) * 10
    p2 = 1 / (1 + np.exp(-(X2 @ true_beta + np.random.normal(true_mu[1], true_tau, sample_size).reshape(sample_size, 1))))
    y2 = np.random.binomial(1,p2)
    X = [X1, X2]
    y = [y1, y2]
    model = LA(X, y).fit(lam_it=10)
    step += [model.step]
# Out:
# In lambad = 0
# The 1 step of mu
# <ipython-input-22-cba37a2349a0>:26: RuntimeWarning: overflow encountered in exp
#   result = np.nan_to_num(tau * np.asarray((np.exp(x @ beta + tau * mu) /\
# <ipython-input-22-cba37a2349a0>:27: RuntimeWarning: overflow encountered in exp
#   (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0)
# <ipython-input-22-cba37a2349a0>:27: RuntimeWarning: overflow encountered in square
#   (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0)
# <ipython-input-22-cba37a2349a0>:26: RuntimeWarning: invalid value encountered in true_divide
#   result = np.nan_to_num(tau * np.asarray((np.exp(x @ beta + tau * mu) /\
# <ipython-input-22-cba37a2349a0>:53: RuntimeWarning: overflow encountered in exp
#   return -tau * sum(-tau**2 * np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1)\
# <ipython-input-22-cba37a2349a0>:53: RuntimeWarning: overflow encountered in multiply
#   return -tau * sum(-tau**2 * np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1)\
# <ipython-input-22-cba37a2349a0>:54: RuntimeWarning: overflow encountered in exp
#   / (1 + np.exp(x @ beta + tau * mu))**3)), nan = 0))
# <ipython-input-22-cba37a2349a0>:54: RuntimeWarning: overflow encountered in power
#   / (1 + np.exp(x @ beta + tau * mu))**3)), nan = 0))
# <ipython-input-22-cba37a2349a0>:53: RuntimeWarning: invalid value encountered in true_divide
#   return -tau * sum(-tau**2 * np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1)\
# <ipython-input-22-cba37a2349a0>:40: RuntimeWarning: overflow encountered in exp
#   result = np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) /\
# <ipython-input-22-cba37a2349a0>:41: RuntimeWarning: overflow encountered in exp
#   (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0)
# <ipython-input-22-cba37a2349a0>:41: RuntimeWarning: overflow encountered in square
#   (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0)
# <ipython-input-22-cba37a2349a0>:40: RuntimeWarning: invalid value encountered in true_divide
#   result = np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) /\
# <ipython-input-22-cba37a2349a0>:56: RuntimeWarning: overflow encountered in exp
#   return -tau * np.sum(-tau * x * np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1)\
# <ipython-input-22-cba37a2349a0>:56: RuntimeWarning: overflow encountered in multiply
#   return -tau * np.sum(-tau * x * np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1)\
# <ipython-input-22-cba37a2349a0>:57: RuntimeWarning: overflow encountered in exp
#   / (1 + np.exp(x @ beta + tau * mu))**3)), nan = 0), axis = 0)
# <ipython-input-22-cba37a2349a0>:57: RuntimeWarning: overflow encountered in power
#   / (1 + np.exp(x @ beta + tau * mu))**3)), nan = 0), axis = 0)
# <ipython-input-22-cba37a2349a0>:56: RuntimeWarning: invalid value encountered in true_divide
#   return -tau * np.sum(-tau * x * np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1)\
# <ipython-input-22-cba37a2349a0>:12: RuntimeWarning: overflow encountered in exp
#   result = np.asarray((np.exp(x @ beta + tau * mu) / (1 + np.exp(x @ beta + tau * mu))))
# <ipython-input-22-cba37a2349a0>:12: RuntimeWarning: invalid value encountered in true_divide
#   result = np.asarray((np.exp(x @ beta + tau * mu) / (1 + np.exp(x @ beta + tau * mu))))
# <ipython-input-22-cba37a2349a0>:62: RuntimeWarning: overflow encountered in multiply
#   * np.nan_to_num((np.exp(x[i] @ beta + tau * mu) * (np.exp(x[i] @ beta + tau * mu) - 1)\
# <ipython-input-22-cba37a2349a0>:63: RuntimeWarning: overflow encountered in power
#   / (1 + np.exp(x[i] @ beta + tau * mu))**3), nan = 0))
# <ipython-input-22-cba37a2349a0>:62: RuntimeWarning: invalid value encountered in true_divide
#   * np.nan_to_num((np.exp(x[i] @ beta + tau * mu) * (np.exp(x[i] @ beta + tau * mu) - 1)\
# <ipython-input-22-cba37a2349a0>:62: RuntimeWarning: overflow encountered in exp
#   * np.nan_to_num((np.exp(x[i] @ beta + tau * mu) * (np.exp(x[i] @ beta + tau * mu) - 1)\
# <ipython-input-22-cba37a2349a0>:63: RuntimeWarning: overflow encountered in exp
#   / (1 + np.exp(x[i] @ beta + tau * mu))**3), nan = 0))
# <ipython-input-22-cba37a2349a0>:85: RuntimeWarning: overflow encountered in exp
#   result = -tau * np.sum( np.nan_to_num(-tau**3 * np.exp(2 * x @ beta + 2 * tau * mu)/(np.exp(x @ beta + tau * mu) + 1)**3\
# <ipython-input-22-cba37a2349a0>:85: RuntimeWarning: overflow encountered in power
#   result = -tau * np.sum( np.nan_to_num(-tau**3 * np.exp(2 * x @ beta + 2 * tau * mu)/(np.exp(x @ beta + tau * mu) + 1)**3\
# <ipython-input-22-cba37a2349a0>:85: RuntimeWarning: invalid value encountered in true_divide
#   result = -tau * np.sum( np.nan_to_num(-tau**3 * np.exp(2 * x @ beta + 2 * tau * mu)/(np.exp(x @ beta + tau * mu) + 1)**3\
# <ipython-input-22-cba37a2349a0>:86: RuntimeWarning: overflow encountered in exp
#   - tau**3 * np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1)/(np.exp(x @ beta + tau * mu) + 1)**3\
# <ipython-input-22-cba37a2349a0>:86: RuntimeWarning: overflow encountered in multiply
#   - tau**3 * np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1)/(np.exp(x @ beta + tau * mu) + 1)**3\
# <ipython-input-22-cba37a2349a0>:86: RuntimeWarning: overflow encountered in power
#   - tau**3 * np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1)/(np.exp(x @ beta + tau * mu) + 1)**3\
# <ipython-input-22-cba37a2349a0>:86: RuntimeWarning: invalid value encountered in true_divide
#   - tau**3 * np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1)/(np.exp(x @ beta + tau * mu) + 1)**3\
# <ipython-input-22-cba37a2349a0>:87: RuntimeWarning: overflow encountered in exp
#   + 3 * tau**3 * np.exp(2 * x @ beta + 2 * tau * mu) * (np.exp(x @ beta + tau * mu) - 1)/(np.exp(x @ beta + tau * mu) + 1)**4, nan = 0) )
# <ipython-input-22-cba37a2349a0>:87: RuntimeWarning: overflow encountered in multiply
#   + 3 * tau**3 * np.exp(2 * x @ beta + 2 * tau * mu) * (np.exp(x @ beta + tau * mu) - 1)/(np.exp(x @ beta + tau * mu) + 1)**4, nan = 0) )
# <ipython-input-22-cba37a2349a0>:87: RuntimeWarning: overflow encountered in power
#   + 3 * tau**3 * np.exp(2 * x @ beta + 2 * tau * mu) * (np.exp(x @ beta + tau * mu) - 1)/(np.exp(x @ beta + tau * mu) + 1)**4, nan = 0) )
# <ipython-input-22-cba37a2349a0>:87: RuntimeWarning: invalid value encountered in true_divide
#   + 3 * tau**3 * np.exp(2 * x @ beta + 2 * tau * mu) * (np.exp(x @ beta + tau * mu) - 1)/(np.exp(x @ beta + tau * mu) + 1)**4, nan = 0) )
# <ipython-input-22-cba37a2349a0>:90: RuntimeWarning: overflow encountered in exp
#   result = -tau * np.sum( np.nan_to_num(tau**2 * x * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:91: RuntimeWarning: overflow encountered in exp
#   * (-4 * np.exp(x @ beta + tau * mu) + np.exp(2 * x @ beta + 2 * tau * mu) + 1)\
# <ipython-input-22-cba37a2349a0>:91: RuntimeWarning: invalid value encountered in add
#   * (-4 * np.exp(x @ beta + tau * mu) + np.exp(2 * x @ beta + 2 * tau * mu) + 1)\
# <ipython-input-22-cba37a2349a0>:90: RuntimeWarning: overflow encountered in multiply
#   result = -tau * np.sum( np.nan_to_num(tau**2 * x * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:92: RuntimeWarning: overflow encountered in exp
#   /(np.exp(x @ beta + tau * mu) + 1)**4, nan = 0), axis = 0 )
# <ipython-input-22-cba37a2349a0>:92: RuntimeWarning: overflow encountered in power
#   /(np.exp(x @ beta + tau * mu) + 1)**4, nan = 0), axis = 0 )
# <ipython-input-22-cba37a2349a0>:90: RuntimeWarning: invalid value encountered in true_divide
#   result = -tau * np.sum( np.nan_to_num(tau**2 * x * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:98: RuntimeWarning: overflow encountered in exp
#   * (-4 * np.exp(x[i] @ beta + tau * mu) + np.exp(2 * x[i] @ beta + 2 * tau * mu) + 1)\
# <ipython-input-22-cba37a2349a0>:99: RuntimeWarning: overflow encountered in power
#   / (np.exp(x[i] @ beta + tau * mu) + 1)**4, nan=0)
# <ipython-input-22-cba37a2349a0>:97: RuntimeWarning: invalid value encountered in true_divide
#   result += x[i].reshape(x.shape[1],1) @ x[i].reshape(1,x.shape[1]) * np.nan_to_num(np.exp(x[i] @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:97: RuntimeWarning: overflow encountered in multiply
#   result += x[i].reshape(x.shape[1],1) @ x[i].reshape(1,x.shape[1]) * np.nan_to_num(np.exp(x[i] @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:97: RuntimeWarning: overflow encountered in exp
#   result += x[i].reshape(x.shape[1],1) @ x[i].reshape(1,x.shape[1]) * np.nan_to_num(np.exp(x[i] @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:98: RuntimeWarning: invalid value encountered in add
#   * (-4 * np.exp(x[i] @ beta + tau * mu) + np.exp(2 * x[i] @ beta + 2 * tau * mu) + 1)\
# <ipython-input-22-cba37a2349a0>:99: RuntimeWarning: overflow encountered in exp
#   / (np.exp(x[i] @ beta + tau * mu) + 1)**4, nan=0)
# <ipython-input-22-cba37a2349a0>:33: RuntimeWarning: overflow encountered in square
#   * np.nan_to_num((np.exp(x[i] @ beta + tau * mu) / (1 + np.exp(x[i] @ beta + tau * tau * mu))**2), nan = 0))
# <ipython-input-22-cba37a2349a0>:33: RuntimeWarning: overflow encountered in exp
#   * np.nan_to_num((np.exp(x[i] @ beta + tau * mu) / (1 + np.exp(x[i] @ beta + tau * tau * mu))**2), nan = 0))
# <ipython-input-22-cba37a2349a0>:33: RuntimeWarning: invalid value encountered in true_divide
#   * np.nan_to_num((np.exp(x[i] @ beta + tau * mu) / (1 + np.exp(x[i] @ beta + tau * tau * mu))**2), nan = 0))
# <ipython-input-22-cba37a2349a0>:45: RuntimeWarning: overflow encountered in exp
#   - tau * sum(mu * np.nan_to_num(mu * np.asarray((np.exp(x @ beta + tau * mu) /\
# <ipython-input-22-cba37a2349a0>:46: RuntimeWarning: overflow encountered in exp
#   (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0))
# <ipython-input-22-cba37a2349a0>:46: RuntimeWarning: overflow encountered in square
#   (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0))
# <ipython-input-22-cba37a2349a0>:45: RuntimeWarning: invalid value encountered in true_divide
#   - tau * sum(mu * np.nan_to_num(mu * np.asarray((np.exp(x @ beta + tau * mu) /\
# <ipython-input-22-cba37a2349a0>:66: RuntimeWarning: overflow encountered in exp
#   result = -tau * np.sum(np.nan_to_num((np.exp(x @ beta + tau * mu) * ((1 - tau * mu) * np.exp(x @ beta + tau * mu) + tau * mu + 1))\
# <ipython-input-22-cba37a2349a0>:66: RuntimeWarning: overflow encountered in multiply
#   result = -tau * np.sum(np.nan_to_num((np.exp(x @ beta + tau * mu) * ((1 - tau * mu) * np.exp(x @ beta + tau * mu) + tau * mu + 1))\
# <ipython-input-22-cba37a2349a0>:67: RuntimeWarning: overflow encountered in exp
#   / (1 + np.exp(x @ beta + tau * mu))**3, nan = 0), axis = 0) - np.sum(np.nan_to_num(tau * np.asarray((np.exp(x @ beta + tau * mu) /\
# <ipython-input-22-cba37a2349a0>:67: RuntimeWarning: overflow encountered in power
#   / (1 + np.exp(x @ beta + tau * mu))**3, nan = 0), axis = 0) - np.sum(np.nan_to_num(tau * np.asarray((np.exp(x @ beta + tau * mu) /\
# <ipython-input-22-cba37a2349a0>:66: RuntimeWarning: invalid value encountered in true_divide
#   result = -tau * np.sum(np.nan_to_num((np.exp(x @ beta + tau * mu) * ((1 - tau * mu) * np.exp(x @ beta + tau * mu) + tau * mu + 1))\
# <ipython-input-22-cba37a2349a0>:68: RuntimeWarning: overflow encountered in exp
#   (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0))
# <ipython-input-22-cba37a2349a0>:68: RuntimeWarning: overflow encountered in square
#   (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0))
# <ipython-input-22-cba37a2349a0>:67: RuntimeWarning: invalid value encountered in true_divide
#   / (1 + np.exp(x @ beta + tau * mu))**3, nan = 0), axis = 0) - np.sum(np.nan_to_num(tau * np.asarray((np.exp(x @ beta + tau * mu) /\
# <ipython-input-22-cba37a2349a0>:71: RuntimeWarning: overflow encountered in exp
#   result = -2 * np.sum(np.nan_to_num(mu * np.asarray((np.exp(x @ beta + tau * mu) /\
# <ipython-input-22-cba37a2349a0>:72: RuntimeWarning: overflow encountered in exp
#   (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0), axis = 0)\
# <ipython-input-22-cba37a2349a0>:72: RuntimeWarning: overflow encountered in square
#   (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0), axis = 0)\
# <ipython-input-22-cba37a2349a0>:71: RuntimeWarning: invalid value encountered in true_divide
#   result = -2 * np.sum(np.nan_to_num(mu * np.asarray((np.exp(x @ beta + tau * mu) /\
# <ipython-input-22-cba37a2349a0>:73: RuntimeWarning: overflow encountered in exp
#   - tau * np.sum( np.nan_to_num(-mu**2 * np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1) /\
# <ipython-input-22-cba37a2349a0>:73: RuntimeWarning: invalid value encountered in multiply
#   - tau * np.sum( np.nan_to_num(-mu**2 * np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1) /\
# <ipython-input-22-cba37a2349a0>:74: RuntimeWarning: overflow encountered in exp
#   (1 + np.exp(x @ beta + tau * mu))**3, nan = 0) )
# <ipython-input-22-cba37a2349a0>:74: RuntimeWarning: overflow encountered in power
#   (1 + np.exp(x @ beta + tau * mu))**3, nan = 0) )
# <ipython-input-22-cba37a2349a0>:105: RuntimeWarning: overflow encountered in exp
#   left = -np.sum(-tau**2 * np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1)\
# <ipython-input-22-cba37a2349a0>:105: RuntimeWarning: overflow encountered in multiply
#   left = -np.sum(-tau**2 * np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1)\
# <ipython-input-22-cba37a2349a0>:106: RuntimeWarning: overflow encountered in exp
#   / (1 + np.exp(x @ beta + tau * mu))**3)), nan = 0))
# <ipython-input-22-cba37a2349a0>:106: RuntimeWarning: overflow encountered in power
#   / (1 + np.exp(x @ beta + tau * mu))**3)), nan = 0))
# <ipython-input-22-cba37a2349a0>:105: RuntimeWarning: invalid value encountered in true_divide
#   left = -np.sum(-tau**2 * np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1)\
# <ipython-input-22-cba37a2349a0>:107: RuntimeWarning: overflow encountered in exp
#   right = -tau * tau * np.sum(np.nan_to_num(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:107: RuntimeWarning: invalid value encountered in multiply
#   right = -tau * tau * np.sum(np.nan_to_num(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:108: RuntimeWarning: overflow encountered in exp
#   + tau * mu * np.exp(2 * x @ beta + 2 * tau * mu)\
# <ipython-input-22-cba37a2349a0>:108: RuntimeWarning: invalid value encountered in multiply
#   + tau * mu * np.exp(2 * x @ beta + 2 * tau * mu)\
# <ipython-input-22-cba37a2349a0>:109: RuntimeWarning: overflow encountered in exp
#   -2 * np.exp(2 * x @ beta + 2 * tau * mu) + tau * mu + 2)\
# <ipython-input-22-cba37a2349a0>:107: RuntimeWarning: overflow encountered in multiply
#   right = -tau * tau * np.sum(np.nan_to_num(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:110: RuntimeWarning: overflow encountered in exp
#   /(np.exp(x @ beta + tau * mu) + 1)**4, nan=0))
# <ipython-input-22-cba37a2349a0>:110: RuntimeWarning: overflow encountered in power
#   /(np.exp(x @ beta + tau * mu) + 1)**4, nan=0))
# <ipython-input-22-cba37a2349a0>:107: RuntimeWarning: invalid value encountered in true_divide
#   right = -tau * tau * np.sum(np.nan_to_num(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:113: RuntimeWarning: overflow encountered in exp
#   left = -2 * np.sum(np.nan_to_num((np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:114: RuntimeWarning: overflow encountered in exp
#   * ((1 - tau * mu) * np.exp(x @ beta + tau * mu) + tau * mu + 1))\
# <ipython-input-22-cba37a2349a0>:113: RuntimeWarning: overflow encountered in multiply
#   left = -2 * np.sum(np.nan_to_num((np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:115: RuntimeWarning: overflow encountered in exp
#   / (1 + np.exp(x @ beta + tau * mu))**3, nan = 0), axis = 0)
# <ipython-input-22-cba37a2349a0>:115: RuntimeWarning: overflow encountered in power
#   / (1 + np.exp(x @ beta + tau * mu))**3, nan = 0), axis = 0)
# <ipython-input-22-cba37a2349a0>:113: RuntimeWarning: invalid value encountered in true_divide
#   left = -2 * np.sum(np.nan_to_num((np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:116: RuntimeWarning: overflow encountered in exp
#   right = -tau * mu * np.sum(np.nan_to_num(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:116: RuntimeWarning: invalid value encountered in multiply
#   right = -tau * mu * np.sum(np.nan_to_num(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:117: RuntimeWarning: overflow encountered in exp
#   + tau * mu * np.exp(2 * x @ beta + 2 * tau * mu)\
# <ipython-input-22-cba37a2349a0>:117: RuntimeWarning: invalid value encountered in multiply
#   + tau * mu * np.exp(2 * x @ beta + 2 * tau * mu)\
# <ipython-input-22-cba37a2349a0>:118: RuntimeWarning: overflow encountered in exp
#   -2 * np.exp(2 * x @ beta + 2 * tau * mu) + tau * mu + 2)\
# <ipython-input-22-cba37a2349a0>:116: RuntimeWarning: overflow encountered in multiply
#   right = -tau * mu * np.sum(np.nan_to_num(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:119: RuntimeWarning: overflow encountered in exp
#   /(np.exp(x @ beta + tau * mu) + 1)**4, nan=0))
# <ipython-input-22-cba37a2349a0>:119: RuntimeWarning: overflow encountered in power
#   /(np.exp(x @ beta + tau * mu) + 1)**4, nan=0))
# <ipython-input-22-cba37a2349a0>:116: RuntimeWarning: invalid value encountered in true_divide
#   right = -tau * mu * np.sum(np.nan_to_num(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:36: RuntimeWarning: overflow encountered in exp
#   result = np.nan_to_num(mu * np.asarray((np.exp(x @ beta + tau * mu) /\
# <ipython-input-22-cba37a2349a0>:37: RuntimeWarning: overflow encountered in exp
#   (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0)
# <ipython-input-22-cba37a2349a0>:37: RuntimeWarning: overflow encountered in square
#   (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0)
# <ipython-input-22-cba37a2349a0>:36: RuntimeWarning: invalid value encountered in true_divide
#   result = np.nan_to_num(mu * np.asarray((np.exp(x @ beta + tau * mu) /\
# <ipython-input-22-cba37a2349a0>:77: RuntimeWarning: overflow encountered in exp
#   left = np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) /\
# <ipython-input-22-cba37a2349a0>:78: RuntimeWarning: overflow encountered in exp
#   (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0)
# <ipython-input-22-cba37a2349a0>:78: RuntimeWarning: overflow encountered in square
#   (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0)
# <ipython-input-22-cba37a2349a0>:77: RuntimeWarning: invalid value encountered in true_divide
#   left = np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) /\
# <ipython-input-22-cba37a2349a0>:80: RuntimeWarning: overflow encountered in exp
#   right = np.nan_to_num(np.asarray((mu * np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1))/\
# <ipython-input-22-cba37a2349a0>:80: RuntimeWarning: invalid value encountered in multiply
#   right = np.nan_to_num(np.asarray((mu * np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1))/\
# <ipython-input-22-cba37a2349a0>:81: RuntimeWarning: overflow encountered in exp
#   (np.exp(x @ beta + tau * mu) + 1)**3), nan = 0)
# <ipython-input-22-cba37a2349a0>:81: RuntimeWarning: overflow encountered in power
#   (np.exp(x @ beta + tau * mu) + 1)**3), nan = 0)
# <ipython-input-22-cba37a2349a0>:122: RuntimeWarning: overflow encountered in exp
#   left = -np.sum(-tau * x * np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1)\
# <ipython-input-22-cba37a2349a0>:122: RuntimeWarning: overflow encountered in multiply
#   left = -np.sum(-tau * x * np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1)\
# <ipython-input-22-cba37a2349a0>:123: RuntimeWarning: overflow encountered in exp
#   / (1 + np.exp(x @ beta + tau * mu))**3)), nan = 0), axis = 0)
# <ipython-input-22-cba37a2349a0>:123: RuntimeWarning: overflow encountered in power
#   / (1 + np.exp(x @ beta + tau * mu))**3)), nan = 0), axis = 0)
# <ipython-input-22-cba37a2349a0>:122: RuntimeWarning: invalid value encountered in true_divide
#   left = -np.sum(-tau * x * np.nan_to_num(np.asarray((np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1)\
# <ipython-input-22-cba37a2349a0>:124: RuntimeWarning: overflow encountered in exp
#   right = -tau * np.sum(x * np.nan_to_num(np.asarray(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:124: RuntimeWarning: invalid value encountered in multiply
#   right = -tau * np.sum(x * np.nan_to_num(np.asarray(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:125: RuntimeWarning: overflow encountered in exp
#   + tau * mu * np.exp(2 * x @ beta + 2 * tau * mu)\
# <ipython-input-22-cba37a2349a0>:125: RuntimeWarning: invalid value encountered in multiply
#   + tau * mu * np.exp(2 * x @ beta + 2 * tau * mu)\
# <ipython-input-22-cba37a2349a0>:126: RuntimeWarning: overflow encountered in exp
#   - np.exp(2 * x @ beta + 2 * tau * mu) + tau * mu + 1)\
# <ipython-input-22-cba37a2349a0>:124: RuntimeWarning: overflow encountered in multiply
#   right = -tau * np.sum(x * np.nan_to_num(np.asarray(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:127: RuntimeWarning: overflow encountered in exp
#   / (np.exp(x @ beta + tau * mu) + 1)**4), nan = 0), axis = 0)
# <ipython-input-22-cba37a2349a0>:127: RuntimeWarning: overflow encountered in power
#   / (np.exp(x @ beta + tau * mu) + 1)**4), nan = 0), axis = 0)
# <ipython-input-22-cba37a2349a0>:124: RuntimeWarning: invalid value encountered in true_divide
#   right = -tau * np.sum(x * np.nan_to_num(np.asarray(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:49: RuntimeWarning: overflow encountered in exp
#   result = np.nan_to_num(mu * np.asarray((np.exp(x @ beta + tau * mu) /\
# <ipython-input-22-cba37a2349a0>:50: RuntimeWarning: overflow encountered in exp
#   (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0)
# <ipython-input-22-cba37a2349a0>:50: RuntimeWarning: overflow encountered in square
#   (1 + np.exp(x @ beta + tau * mu))**2)), nan = 0)
# <ipython-input-22-cba37a2349a0>:49: RuntimeWarning: invalid value encountered in true_divide
#   result = np.nan_to_num(mu * np.asarray((np.exp(x @ beta + tau * mu) /\
# <ipython-input-22-cba37a2349a0>:73: RuntimeWarning: invalid value encountered in true_divide
#   - tau * np.sum( np.nan_to_num(-mu**2 * np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1) /\
# <ipython-input-22-cba37a2349a0>:107: RuntimeWarning: invalid value encountered in add
#   right = -tau * tau * np.sum(np.nan_to_num(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:116: RuntimeWarning: invalid value encountered in add
#   right = -tau * mu * np.sum(np.nan_to_num(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:80: RuntimeWarning: invalid value encountered in true_divide
#   right = np.nan_to_num(np.asarray((mu * np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1))/\
# <ipython-input-22-cba37a2349a0>:124: RuntimeWarning: invalid value encountered in add
#   right = -tau * np.sum(x * np.nan_to_num(np.asarray(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:73: RuntimeWarning: overflow encountered in multiply
#   - tau * np.sum( np.nan_to_num(-mu**2 * np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1) /\
# <ipython-input-22-cba37a2349a0>:107: RuntimeWarning: invalid value encountered in subtract
#   right = -tau * tau * np.sum(np.nan_to_num(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:116: RuntimeWarning: invalid value encountered in subtract
#   right = -tau * mu * np.sum(np.nan_to_num(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:80: RuntimeWarning: overflow encountered in multiply
#   right = np.nan_to_num(np.asarray((mu * np.exp(x @ beta + tau * mu) * (np.exp(x @ beta + tau * mu) - 1))/\
# Get out of iteration (delta > 10^(2)
# score:
#  [2.22206653]
#
# In lambad = 1
# The 1 step of mu
# Get out of iteration (delta > 10^(2)
# score:
#  [-121950.70443638]
#
# In lambad = 2
# The 1 step of mu
# <ipython-input-22-cba37a2349a0>:124: RuntimeWarning: invalid value encountered in subtract
#   right = -tau * np.sum(x * np.nan_to_num(np.asarray(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:91: RuntimeWarning: overflow encountered in multiply
#   * (-4 * np.exp(x @ beta + tau * mu) + np.exp(2 * x @ beta + 2 * tau * mu) + 1)\
# <ipython-input-22-cba37a2349a0>:98: RuntimeWarning: overflow encountered in multiply
#   * (-4 * np.exp(x[i] @ beta + tau * mu) + np.exp(2 * x[i] @ beta + 2 * tau * mu) + 1)\
# <ipython-input-22-cba37a2349a0>:107: RuntimeWarning: overflow encountered in subtract
#   right = -tau * tau * np.sum(np.nan_to_num(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:116: RuntimeWarning: overflow encountered in subtract
#   right = -tau * mu * np.sum(np.nan_to_num(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
# <ipython-input-22-cba37a2349a0>:109: RuntimeWarning: overflow encountered in multiply
#   -2 * np.exp(2 * x @ beta + 2 * tau * mu) + tau * mu + 2)\
# <ipython-input-22-cba37a2349a0>:118: RuntimeWarning: overflow encountered in multiply
#   -2 * np.exp(2 * x @ beta + 2 * tau * mu) + tau * mu + 2)\
# <ipython-input-22-cba37a2349a0>:85: RuntimeWarning: overflow encountered in multiply
#   result = -tau * np.sum( np.nan_to_num(-tau**3 * np.exp(2 * x @ beta + 2 * tau * mu)/(np.exp(x @ beta + tau * mu) + 1)**3\
# <ipython-input-22-cba37a2349a0>:108: RuntimeWarning: overflow encountered in multiply
#   + tau * mu * np.exp(2 * x @ beta + 2 * tau * mu)\
# <ipython-input-22-cba37a2349a0>:117: RuntimeWarning: overflow encountered in multiply
#   + tau * mu * np.exp(2 * x @ beta + 2 * tau * mu)\
# <ipython-input-22-cba37a2349a0>:125: RuntimeWarning: overflow encountered in multiply
#   + tau * mu * np.exp(2 * x @ beta + 2 * tau * mu)\
# Done with iteration
# The 2 step of mu
# <ipython-input-22-cba37a2349a0>:114: RuntimeWarning: overflow encountered in multiply
#   * ((1 - tau * mu) * np.exp(x @ beta + tau * mu) + tau * mu + 1))\
# <ipython-input-22-cba37a2349a0>:17: RuntimeWarning: divide by zero encountered in log
#   + np.nan_to_num(np.log(tau * (np.sqrt(2 * np.pi))**(-1) * np.exp(-mu**2/2)), nan=0)
# <ipython-input-49-9b3f34d14e0c>:155: RuntimeWarning: overflow encountered in add
#   score += l(self.X[i], self.y[i], self.mu[i], self.beta, self.tau) - sum(self.lam * (self.beta) **2)
# Done with iteration
# score:
#  [-inf]
#
# In lambad = 3
# The 1 step of mu
# <ipython-input-22-cba37a2349a0>:124: RuntimeWarning: overflow encountered in subtract
#   right = -tau * np.sum(x * np.nan_to_num(np.asarray(np.exp(x @ beta + tau * mu) * (-4 * tau * mu * np.exp(x @ beta + tau * mu)\
# Get out of iteration (delta > 10^(2)
# score:
#  [-340659.21728433]
#
# In lambad = 4
# The 1 step of mu
# Get out of iteration (delta > 10^(2)
# score:
#  [-35800.12686666]
#
# In lambad = 5
# The 1 step of mu
# <ipython-input-22-cba37a2349a0>:17: RuntimeWarning: invalid value encountered in log
#   + np.nan_to_num(np.log(tau * (np.sqrt(2 * np.pi))**(-1) * np.exp(-mu**2/2)), nan=0)
# Get out of iteration (delta > 10^(2)
# score:
#  [-5478060.03725237]
#
# In lambad = 6
# The 1 step of mu
# Get out of iteration (delta > 10^(2)
# score:
#  [-1.79769313e+308]
#
# In lambad = 7
# The 1 step of mu
# Error: NaN beta, rested to 0
# score:
#  [nan]
#
# Error: NaN score
# <ipython-input-22-cba37a2349a0>:32: RuntimeWarning: overflow encountered in multiply
#   result += -np.asarray(x[i].reshape(x.shape[1],1) @ x[i].reshape(1,x.shape[1])\
# <ipython-input-22-cba37a2349a0>:32: RuntimeWarning: overflow encountered in add
#   result += -np.asarray(x[i].reshape(x.shape[1],1) @ x[i].reshape(1,x.shape[1])\
# <ipython-input-22-cba37a2349a0>:32: RuntimeWarning: invalid value encountered in add
#   result += -np.asarray(x[i].reshape(x.shape[1],1) @ x[i].reshape(1,x.shape[1])\
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-50-bf7c146d62c3> in <module>
#      14     X = [X1, X2]
#      15     y = [y1, y2]
# ---> 16     model = LA(X, y).fit(lam_it=10)
#      17     step += [model.step]
#
# <ipython-input-49-9b3f34d14e0c> in fit(self, lam_it, lam_step, mu_it, theta_it)
#     170
#     171         # Returning data
# --> 172         optimized_beta[0] = optimized_beta[0] + np.mean(optimized_tau * optimized_mu)
#     173         self.beta = optimized_beta
#     174         self.mu = optimized_mu
#
# UnboundLocalError: local variable 'optimized_beta' referenced before assignment

# %%
step
# Out:
# []

# %%
sample_size
# Out:
# 100
