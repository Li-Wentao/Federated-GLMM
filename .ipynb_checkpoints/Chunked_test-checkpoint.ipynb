# %%
# from GLMM_LA import *
from GLMM_GH import *

# %%
##################### Simulation with Penn ############################
import os
truth = np.array([-1.5,0.1,-0.5,-0.3,0.4,-0.2,-0.25,0.35,-0.1,0.5]).reshape(10, 1)
var_name = []
for i in range(10):
    var_name += ['X' + str(i+1)]
import sys

# %%
file_dir = '../Simulation_data_GLMM/Setting_2/'
f = '2Sites_500PatientsEachSite_LargeVar4_Dataset14.csv'
df = pd.read_csv(file_dir + f, index_col=0)
# Load data
data1 = np.array(df[df['Site_ID'] == 1][var_name])
data2 = np.array(df[df['Site_ID'] == 2][var_name])
data = [data1, data2]
out1 = np.array(df[df['Site_ID'] == 1]['y']).reshape(500,1)
out2 = np.array(df[df['Site_ID'] == 2]['y']).reshape(500,1)
out = [out1, out2]

# %% [markdown]
# # LA

# %%
start_time = time.time()
[beta, mu] = LA(data, out)
t = time.time() - start_time
t = time.time() - start_time
output(data, beta, truth, t)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:33: RuntimeWarning: overflow encountered in exp
#   result = np.nan_to_num(- np.asarray((np.exp(x @ beta_0 + mu) / (1 + np.exp(x @ beta_0 + mu)) ** 2)), nan=0)
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:33: RuntimeWarning: overflow encountered in square
#   result = np.nan_to_num(- np.asarray((np.exp(x @ beta_0 + mu) / (1 + np.exp(x @ beta_0 + mu)) ** 2)), nan=0)
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:33: RuntimeWarning: invalid value encountered in true_divide
#   result = np.nan_to_num(- np.asarray((np.exp(x @ beta_0 + mu) / (1 + np.exp(x @ beta_0 + mu)) ** 2)), nan=0)
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:49: RuntimeWarning: overflow encountered in exp
#   return sum(- np.nan_to_num(np.asarray((np.exp(x @ beta_0 + mu) * (np.exp(x @ beta_0 + mu) - 1) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:49: RuntimeWarning: overflow encountered in multiply
#   return sum(- np.nan_to_num(np.asarray((np.exp(x @ beta_0 + mu) * (np.exp(x @ beta_0 + mu) - 1) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:50: RuntimeWarning: overflow encountered in exp
#   / (1 + np.exp(x @ beta_0 + mu)) ** 3)), nan=0))
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:50: RuntimeWarning: overflow encountered in power
#   / (1 + np.exp(x @ beta_0 + mu)) ** 3)), nan=0))
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:49: RuntimeWarning: invalid value encountered in true_divide
#   return sum(- np.nan_to_num(np.asarray((np.exp(x @ beta_0 + mu) * (np.exp(x @ beta_0 + mu) - 1) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:37: RuntimeWarning: overflow encountered in exp
#   result = np.nan_to_num(np.asarray((np.exp(x @ beta_0 + mu) / (1 + np.exp(x @ beta_0 + mu)) ** 2)), nan=0)
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:37: RuntimeWarning: overflow encountered in square
#   result = np.nan_to_num(np.asarray((np.exp(x @ beta_0 + mu) / (1 + np.exp(x @ beta_0 + mu)) ** 2)), nan=0)
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:37: RuntimeWarning: invalid value encountered in true_divide
#   result = np.nan_to_num(np.asarray((np.exp(x @ beta_0 + mu) / (1 + np.exp(x @ beta_0 + mu)) ** 2)), nan=0)
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:53: RuntimeWarning: overflow encountered in exp
#   return np.sum(- x * np.nan_to_num(np.asarray((np.exp(x @ beta_0 + mu) * (np.exp(x @ beta_0 + mu) - 1) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:53: RuntimeWarning: overflow encountered in multiply
#   return np.sum(- x * np.nan_to_num(np.asarray((np.exp(x @ beta_0 + mu) * (np.exp(x @ beta_0 + mu) - 1) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:54: RuntimeWarning: overflow encountered in exp
#   / (1 + np.exp(x @ beta_0 + mu)) ** 3)), nan=0), axis=0)
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:54: RuntimeWarning: overflow encountered in power
#   / (1 + np.exp(x @ beta_0 + mu)) ** 3)), nan=0), axis=0)
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:53: RuntimeWarning: invalid value encountered in true_divide
#   return np.sum(- x * np.nan_to_num(np.asarray((np.exp(x @ beta_0 + mu) * (np.exp(x @ beta_0 + mu) - 1) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:15: RuntimeWarning: overflow encountered in exp
#   result = np.asarray((np.exp(x @ beta_0 + mu) / (1 + np.exp(x @ beta_0 + mu))))
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:15: RuntimeWarning: invalid value encountered in true_divide
#   result = np.asarray((np.exp(x @ beta_0 + mu) / (1 + np.exp(x @ beta_0 + mu))))
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:16: RuntimeWarning: overflow encountered in exp
#   if np.exp(x @ beta_0 + mu).max() == np.inf:
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:61: RuntimeWarning: overflow encountered in power
#   / (1 + np.exp(x[i] @ beta_0 + mu)) ** 3), nan=0))
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:60: RuntimeWarning: overflow encountered in exp
#   * np.nan_to_num((np.exp(x[i] @ beta_0 + mu) * (np.exp(x[i] @ beta_0 + mu) - 1) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:61: RuntimeWarning: overflow encountered in exp
#   / (1 + np.exp(x[i] @ beta_0 + mu)) ** 3), nan=0))
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:60: RuntimeWarning: invalid value encountered in true_divide
#   * np.nan_to_num((np.exp(x[i] @ beta_0 + mu) * (np.exp(x[i] @ beta_0 + mu) - 1) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:60: RuntimeWarning: overflow encountered in multiply
#   * np.nan_to_num((np.exp(x[i] @ beta_0 + mu) * (np.exp(x[i] @ beta_0 + mu) - 1) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:65: RuntimeWarning: overflow encountered in exp
#   result = sum(- np.nan_to_num((np.exp(x @ beta_0 + mu) * (np.exp(x @ beta_0 + mu) - 1) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:65: RuntimeWarning: overflow encountered in multiply
#   result = sum(- np.nan_to_num((np.exp(x @ beta_0 + mu) * (np.exp(x @ beta_0 + mu) - 1) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:66: RuntimeWarning: overflow encountered in exp
#   / (1 + np.exp(x @ beta_0 + mu)) ** 3), nan=0) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:66: RuntimeWarning: overflow encountered in power
#   / (1 + np.exp(x @ beta_0 + mu)) ** 3), nan=0) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:65: RuntimeWarning: invalid value encountered in true_divide
#   result = sum(- np.nan_to_num((np.exp(x @ beta_0 + mu) * (np.exp(x @ beta_0 + mu) - 1) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:67: RuntimeWarning: overflow encountered in exp
#   + np.nan_to_num((3 * np.exp(2 * (x @ beta_0 + mu)) * (np.exp(x @ beta_0 + mu) - 1) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:67: RuntimeWarning: overflow encountered in multiply
#   + np.nan_to_num((3 * np.exp(2 * (x @ beta_0 + mu)) * (np.exp(x @ beta_0 + mu) - 1) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:68: RuntimeWarning: overflow encountered in exp
#   / (1 + np.exp(x @ beta_0 + mu)) ** 4), nan=0) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:68: RuntimeWarning: overflow encountered in power
#   / (1 + np.exp(x @ beta_0 + mu)) ** 4), nan=0) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:67: RuntimeWarning: invalid value encountered in true_divide
#   + np.nan_to_num((3 * np.exp(2 * (x @ beta_0 + mu)) * (np.exp(x @ beta_0 + mu) - 1) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:69: RuntimeWarning: overflow encountered in exp
#   - np.nan_to_num((np.exp(2 * (x @ beta_0 + mu)) / (1 + np.exp(x @ beta_0 + mu)) ** 3), nan=0) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:69: RuntimeWarning: overflow encountered in power
#   - np.nan_to_num((np.exp(2 * (x @ beta_0 + mu)) / (1 + np.exp(x @ beta_0 + mu)) ** 3), nan=0) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:69: RuntimeWarning: invalid value encountered in true_divide
#   - np.nan_to_num((np.exp(2 * (x @ beta_0 + mu)) / (1 + np.exp(x @ beta_0 + mu)) ** 3), nan=0) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:74: RuntimeWarning: overflow encountered in exp
#   result = np.sum(- x * np.asarray(np.nan_to_num((np.exp(x @ beta_0 + mu) * (np.exp(x @ beta_0 + mu) - 1) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:74: RuntimeWarning: overflow encountered in multiply
#   result = np.sum(- x * np.asarray(np.nan_to_num((np.exp(x @ beta_0 + mu) * (np.exp(x @ beta_0 + mu) - 1) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:75: RuntimeWarning: overflow encountered in exp
#   / (1 + np.exp(x @ beta_0 + mu)) ** 3), nan=0) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:75: RuntimeWarning: overflow encountered in power
#   / (1 + np.exp(x @ beta_0 + mu)) ** 3), nan=0) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:74: RuntimeWarning: invalid value encountered in true_divide
#   result = np.sum(- x * np.asarray(np.nan_to_num((np.exp(x @ beta_0 + mu) * (np.exp(x @ beta_0 + mu) - 1) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:77: RuntimeWarning: overflow encountered in exp
#   (3 * np.exp(2 * (x @ beta_0 + mu)) * (np.exp(x @ beta_0 + mu) - 1) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:77: RuntimeWarning: overflow encountered in multiply
#   (3 * np.exp(2 * (x @ beta_0 + mu)) * (np.exp(x @ beta_0 + mu) - 1) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:78: RuntimeWarning: overflow encountered in exp
#   / (1 + np.exp(x @ beta_0 + mu)) ** 4), nan=0) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:78: RuntimeWarning: overflow encountered in power
#   / (1 + np.exp(x @ beta_0 + mu)) ** 4), nan=0) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:77: RuntimeWarning: invalid value encountered in true_divide
#   (3 * np.exp(2 * (x @ beta_0 + mu)) * (np.exp(x @ beta_0 + mu) - 1) \
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:80: RuntimeWarning: overflow encountered in exp
#   (np.exp(2 * (x @ beta_0 + mu)) / (1 + np.exp(x @ beta_0 + mu)) ** 3), nan=0))
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:80: RuntimeWarning: overflow encountered in power
#   (np.exp(2 * (x @ beta_0 + mu)) / (1 + np.exp(x @ beta_0 + mu)) ** 3), nan=0))
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:80: RuntimeWarning: invalid value encountered in true_divide
#   (np.exp(2 * (x @ beta_0 + mu)) / (1 + np.exp(x @ beta_0 + mu)) ** 3), nan=0))
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:44: RuntimeWarning: overflow encountered in exp
#   * np.nan_to_num((np.exp(x[i] @ beta_0 + mu) / (1 + np.exp(x[i] @ beta_0 + mu)) ** 2),
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:44: RuntimeWarning: invalid value encountered in true_divide
#   * np.nan_to_num((np.exp(x[i] @ beta_0 + mu) / (1 + np.exp(x[i] @ beta_0 + mu)) ** 2),
# /Users/wli17/Documents/GLMM/GLMM/GLMM_LA.py:44: RuntimeWarning: overflow encountered in square
#   * np.nan_to_num((np.exp(x[i] @ beta_0 + mu) / (1 + np.exp(x[i] @ beta_0 + mu)) ** 2),
# --- 176.42389822006226 seconds ---

# %%
output(data, beta, truth, t)
# Out:
#      Truth      Coef   Std.Err         z   P-value    [0.025    0.975]  \
# X1   -1.50 -0.486885  0.109131 -4.461458  0.000008 -0.700778 -0.272991
# X2    0.10 -0.281354  0.227106 -1.238866  0.215395 -0.726475  0.163766
# X3   -0.50 -0.273819  0.152415 -1.796538  0.072409 -0.572548  0.024909
# X4   -0.30 -0.264321  0.139411 -1.895978  0.057963 -0.537563  0.008920
# X5    0.40  0.490236  0.144115  3.401698  0.000670  0.207776  0.772696
# X6   -0.20 -0.086231  0.073513 -1.172999  0.240796 -0.230313  0.057852
# X7   -0.25 -0.173791  0.047790 -3.636530  0.000276 -0.267458 -0.080124
# X8    0.35  0.295978  0.249265  1.187401  0.235070 -0.192573  0.784529
# X9   -0.10  0.523823  0.173856  3.012964  0.002587  0.183071  0.864575
# X10   0.50  0.457421  0.120505  3.795886  0.000147  0.221237  0.693606
#
#         RunTime
# X1   176.422084
# X2   176.422084
# X3   176.422084
# X4   176.422084
# X5   176.422084
# X6   176.422084
# X7   176.422084
# X8   176.422084
# X9   176.422084
# X10  176.422084

# %% [markdown]
# # GH

# %%
start_time = time.time()
[beta, mu] = GH(3, data, out)
t = time.time() - start_time
t = time.time() - start_time
output(data, beta, truth, t)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 1095.6266140937805 seconds ---

# %%
output(data, beta, truth, t)
# Out:
#      Truth      Coef   Std.Err         z   P-value    [0.025    0.975]  \
# X1   -1.50 -0.145235  0.106952 -1.357940  0.174483 -0.354857  0.064388
# X2    0.10 -0.386933  0.220669 -1.753452  0.079525 -0.819437  0.045571
# X3   -0.50 -0.316605  0.147914 -2.140473  0.032317 -0.606511 -0.026700
# X4   -0.30 -0.289531  0.135737 -2.133020  0.032923 -0.555571 -0.023490
# X5    0.40  0.580865  0.141521  4.104451  0.000041  0.303489  0.858240
# X6   -0.20 -0.096797  0.071729 -1.349481  0.177182 -0.237383  0.043789
# X7   -0.25 -0.185441  0.046658 -3.974454  0.000071 -0.276890 -0.093993
# X8    0.35  0.431752  0.243178  1.775456  0.075823 -0.044868  0.908373
# X9   -0.10  0.651800  0.170086  3.832178  0.000127  0.318438  0.985163
# X10   0.50  0.530041  0.117496  4.511122  0.000006  0.299752  0.760330
#
#          RunTime
# X1   1095.620686
# X2   1095.620686
# X3   1095.620686
# X4   1095.620686
# X5   1095.620686
# X6   1095.620686
# X7   1095.620686
# X8   1095.620686
# X9   1095.620686
# X10  1095.620686

# %%
1095.620686/60
# Out:
# 18.260344766666666
